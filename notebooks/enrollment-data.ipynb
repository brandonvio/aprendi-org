# %%
import csv
import json
from dotenv import load_dotenv
from pynamodb.models import Model
from pynamodb.attributes import UnicodeAttribute, NumberAttribute

# %%
load_dotenv(verbose=True)
# Out:
# True

# %%
class SingleTableModel(Model):
    class Meta:
        table_name = "aprendi_org_table"
        region = 'us-west-2' 
        # host = "http://localhost:8000"
    pk = UnicodeAttribute(hash_key=True)
    sk = UnicodeAttribute(range_key=True)
    data = UnicodeAttribute(null=True)
    
    @classmethod
    def teacher_pk(cls, id):
        return f"TEACHER#{id}"

    @classmethod
    def student_pk(cls, id):
        return f"STUDENT#{id}"

    @classmethod
    def course_pk(cls, id):
        return f"COURSE#{id}"

    @classmethod
    def semester_pk(cls, id):
        return f"SEMESTER#{id}"
    
    @classmethod
    def course_sk(cls):
        return f"METADATA"
        
    @classmethod
    def teacher_sk(cls):
        return f"METADATA"

    @classmethod
    def course_sk(cls):
        return f"METADATA"

    @classmethod
    def student_sk(cls):
        return f"METADATA"

    @classmethod
    def semester_sk(cls):
        return f"METADATA"
    
    # semester schedule
    @classmethod
    def semester_schedule_pk(cls, semester_id):
        return f"SCHEDULE#SEMESTER#{id}"
    
    @classmethod
    def semester_schedule_sk(cls, course_id, period_id, teacher_id):
        return f"COURSE##{course_id}#PERIOD##{period_id}#TEACHER##{teacher_id}"

# %%
if not SingleTableModel.exists():
        SingleTableModel.create_table(read_capacity_units=100, write_capacity_units=100, wait=True)

# %%
def get_reader(csv_filename):
    with open('data/' + csv_filename, 'r') as csvfile:
        reader = csv.reader(csvfile)
        return list(reader)
    
def empty_table():
    for item in SingleTableModel.scan():
        item.delete()

def seed_courses():
    reader = get_reader("courses.csv")
    for row in reader:
        course_id, course_name = row
        course = SingleTableModel(pk=SingleTableModel.course_pk(course_id), sk=SingleTableModel.course_sk())
        data = {
            "course_name": course_name
        }
        course.data = json.dumps(data)
        course.save()

def seed_students():
    reader = get_reader("students.csv")
    for row in reader:
        id, last, first, dob = row
        student = SingleTableModel(pk=SingleTableModel.student_pk(id), sk=SingleTableModel.student_sk())
        data = {
            "first": first,
            "last": last,
            "dob": dob
        }
        student.data = json.dumps(data)
        student.save()

def seed_teachers():
    reader = get_reader("teachers.csv")
    for row in reader:
        id, last, first, dob, degree = row
        teacher = SingleTableModel(pk=SingleTableModel.teacher_pk(id), sk=SingleTableModel.teacher_sk())
        data = {
            "first": first,
            "last": last,
            "dob": dob,
            "degree": degree
        }
        teacher.data = json.dumps(data)
        teacher.save()
        
def seed_semester():
    semester1 = SingleTableModel(pk=SingleTableModel.semester_pk("2023S1"), sk=SingleTableModel.semester_sk())
    data = {}
    data["description"] = "2023 Semester 1"
    semester1.data = json.dumps(data)
    semester1.save()

def seed():
    empty_table()
    seed_semester()
    seed_courses()
    seed_students()
    seed_teachers()

# %%
seed()

# %%
result = SingleTableModel.get("TEACHER#100", "METADATA")

# %%
data = json.loads(result.data)
print(data["first"])
# Out:
# Liam

# %%
for item in SingleTableModel.scan():
    print(item, item.data)
# Out:
# aprendi_org_table<COURSE#181, METADATA> {"course_name": "Agricultural Science"}
# aprendi_org_table<STUDENT#175, METADATA> {"first": "Jack", "last": "Harris", "dob": "1994-05-31"}
# aprendi_org_table<STUDENT#102, METADATA> {"first": "Noah", "last": "Smith", "dob": "1988-03-10"}
# aprendi_org_table<TEACHER#115, METADATA> {"first": "Evelyn", "last": "Thomas", "dob": "1984-11-27", "degree": "Masters of Public Health"}
# aprendi_org_table<COURSE#188, METADATA> {"course_name": "Transportation Studies"}
# aprendi_org_table<TEACHER#175, METADATA> {"first": "Jack", "last": "Harris", "dob": "1994-05-31", "degree": "Masters of Social Work"}
# aprendi_org_table<TEACHER#129, METADATA> {"first": "Daniel", "last": "King", "dob": "1985-04-25", "degree": "Masters of Science in Chemistry"}
# aprendi_org_table<TEACHER#142, METADATA> {"first": "Aiden", "last": "Martin", "dob": "1980-08-02", "degree": "PhD in Computer Science"}
# aprendi_org_table<TEACHER#164, METADATA> {"first": "Lincoln", "last": "Miller", "dob": "1998-06-10", "degree": "PhD in Anthropology"}
# aprendi_org_table<TEACHER#131, METADATA> {"first": "Jackson", "last": "Ward", "dob": "1981-11-11", "degree": "Masters of Political Science"}
# aprendi_org_table<COURSE#113, METADATA> {"course_name": "Economics"}
# aprendi_org_table<COURSE#153, METADATA> {"course_name": "Religious Studies"}
# aprendi_org_table<TEACHER#167, METADATA> {"first": "Layla", "last": "Johnson", "dob": "1977-11-21", "degree": "Masters of Music"}
# aprendi_org_table<TEACHER#168, METADATA> {"first": "Oliver", "last": "Smith", "dob": "1989-09-14", "degree": "PhD in Economics"}
# aprendi_org_table<STUDENT#147, METADATA> {"first": "Aria", "last": "Moore", "dob": "1989-08-30"}
# aprendi_org_table<TEACHER#122, METADATA> {"first": "Evelyn", "last": "Lewis", "dob": "1989-09-09", "degree": "PhD in Linguistics"}
# aprendi_org_table<COURSE#160, METADATA> {"course_name": "Asian Studies"}
# aprendi_org_table<COURSE#141, METADATA> {"course_name": "Chemical Engineering"}
# aprendi_org_table<COURSE#107, METADATA> {"course_name": "Geography"}
# aprendi_org_table<COURSE#108, METADATA> {"course_name": "English Literature"}
# aprendi_org_table<COURSE#194, METADATA> {"course_name": "Music Production"}
# aprendi_org_table<STUDENT#105, METADATA> {"first": "Ava", "last": "Garcia", "dob": "1982-06-25"}
# aprendi_org_table<COURSE#133, METADATA> {"course_name": "Finance"}
# aprendi_org_table<STUDENT#180, METADATA> {"first": "Samuel", "last": "King", "dob": "1978-06-27"}
# aprendi_org_table<COURSE#168, METADATA> {"course_name": "Dentistry"}
# aprendi_org_table<TEACHER#134, METADATA> {"first": "Naomi", "last": "Turner", "dob": "1984-03-23", "degree": "PhD in Sociology"}
# aprendi_org_table<COURSE#156, METADATA> {"course_name": "Renaissance Studies"}
# aprendi_org_table<COURSE#185, METADATA> {"course_name": "Conservation"}
# aprendi_org_table<STUDENT#148, METADATA> {"first": "Ethan", "last": "Thomas", "dob": "1971-06-23"}
# aprendi_org_table<COURSE#179, METADATA> {"course_name": "Secondary Education"}
# aprendi_org_table<TEACHER#112, METADATA> {"first": "Amelia", "last": "Gonzalez", "dob": "1975-07-17", "degree": "Masters of Science in Environmental Science"}
# aprendi_org_table<COURSE#167, METADATA> {"course_name": "Nursing"}
# aprendi_org_table<COURSE#127, METADATA> {"course_name": "Theater Arts"}
# aprendi_org_table<COURSE#142, METADATA> {"course_name": "Architecture"}
# aprendi_org_table<TEACHER#107, METADATA> {"first": "Ethan", "last": "Davis", "dob": "1989-10-31", "degree": "PhD in Economics"}
# aprendi_org_table<STUDENT#160, METADATA> {"first": "Lucas", "last": "Perez", "dob": "1970-03-06"}
# aprendi_org_table<STUDENT#103, METADATA> {"first": "Emma", "last": "Brown", "dob": "1979-12-05"}
# aprendi_org_table<TEACHER#130, METADATA> {"first": "Chloe", "last": "Wright", "dob": "1997-01-18", "degree": "PhD in Education"}
# aprendi_org_table<STUDENT#137, METADATA> {"first": "Aria", "last": "Smith", "dob": "2000-08-05"}
# aprendi_org_table<TEACHER#146, METADATA> {"first": "Lincoln", "last": "White", "dob": "1977-11-06", "degree": "PhD in History"}
# aprendi_org_table<STUDENT#123, METADATA> {"first": "Liam", "last": "Lee", "dob": "1999-07-03"}
# aprendi_org_table<COURSE#112, METADATA> {"course_name": "Political Science"}
# aprendi_org_table<STUDENT#165, METADATA> {"first": "Eva", "last": "Moore", "dob": "1981-04-03"}
# aprendi_org_table<STUDENT#168, METADATA> {"first": "Oliver", "last": "Smith", "dob": "1989-09-14"}
# aprendi_org_table<STUDENT#129, METADATA> {"first": "Daniel", "last": "King", "dob": "1985-04-25"}
# aprendi_org_table<SEMESTER#2023S1, METADATA> {"description": "2023 Semester 1"}
# aprendi_org_table<COURSE#189, METADATA> {"course_name": "Logistics"}
# aprendi_org_table<STUDENT#145, METADATA> {"first": "Lily", "last": "Walker", "dob": "1996-01-13"}
# aprendi_org_table<COURSE#172, METADATA> {"course_name": "Criminal Justice"}
# aprendi_org_table<COURSE#166, METADATA> {"course_name": "Pharmacology"}
# aprendi_org_table<COURSE#158, METADATA> {"course_name": "World Cultures"}
# aprendi_org_table<COURSE#169, METADATA> {"course_name": "Medicine"}
# aprendi_org_table<STUDENT#174, METADATA> {"first": "Aria", "last": "Lee", "dob": "1980-08-06"}
# aprendi_org_table<TEACHER#141, METADATA> {"first": "Stella", "last": "Harris", "dob": "1998-11-08", "degree": "Masters of Science in Environmental Science"}
# aprendi_org_table<TEACHER#152, METADATA> {"first": "Evelyn", "last": "Harris", "dob": "1999-09-28", "degree": "PhD in Environmental Science"}
# aprendi_org_table<COURSE#120, METADATA> {"course_name": "Environmental Science"}
# aprendi_org_table<STUDENT#110, METADATA> {"first": "Sophia", "last": "Hernandez", "dob": "1993-01-28"}
# aprendi_org_table<COURSE#176, METADATA> {"course_name": "Educational Studies"}
# aprendi_org_table<TEACHER#161, METADATA> {"first": "Lily", "last": "Anderson", "dob": "1984-12-30", "degree": "Masters of Fine Arts in Visual Arts"}
# aprendi_org_table<TEACHER#135, METADATA> {"first": "Lucas", "last": "Perez", "dob": "1972-12-17", "degree": "Masters of Science in Physics"}
# aprendi_org_table<STUDENT#162, METADATA> {"first": "Avery", "last": "Ward", "dob": "1992-10-23"}
# aprendi_org_table<COURSE#123, METADATA> {"course_name": "Botany"}
# aprendi_org_table<STUDENT#132, METADATA> {"first": "Victoria", "last": "Mitchell", "dob": "1979-09-05"}
# aprendi_org_table<STUDENT#179, METADATA> {"first": "Eli", "last": "Clark", "dob": "1992-09-03"}
# aprendi_org_table<COURSE#177, METADATA> {"course_name": "Special Education"}
# aprendi_org_table<TEACHER#121, METADATA> {"first": "Sofia", "last": "Rodriguez", "dob": "1973-11-16", "degree": "Masters of Social Science"}
# aprendi_org_table<TEACHER#105, METADATA> {"first": "Ava", "last": "Garcia", "dob": "1982-06-25", "degree": "Masters of Arts in History"}
# aprendi_org_table<TEACHER#133, METADATA> {"first": "Leo", "last": "Adams", "dob": "1995-06-29", "degree": "Masters of Fine Arts in Visual Arts"}
# aprendi_org_table<TEACHER#177, METADATA> {"first": "Zoe", "last": "White", "dob": "1988-01-17", "degree": "Masters of Science in Nursing"}
# aprendi_org_table<COURSE#119, METADATA> {"course_name": "Astronomy"}
# aprendi_org_table<COURSE#193, METADATA> {"course_name": "Event Planning"}
# aprendi_org_table<STUDENT#161, METADATA> {"first": "Lily", "last": "Anderson", "dob": "1984-12-30"}
# aprendi_org_table<STUDENT#114, METADATA> {"first": "Harper", "last": "Anderson", "dob": "1997-02-03"}
# aprendi_org_table<TEACHER#174, METADATA> {"first": "Aria", "last": "Lee", "dob": "1980-08-06", "degree": "PhD in History"}
# aprendi_org_table<STUDENT#119, METADATA> {"first": "Abigail", "last": "Martin", "dob": "1992-03-30"}
# aprendi_org_table<STUDENT#143, METADATA> {"first": "Ava", "last": "Thompson", "dob": "1994-05-26"}
# aprendi_org_table<COURSE#199, METADATA> {"course_name": "Poetry"}
# aprendi_org_table<TEACHER#101, METADATA> {"first": "Olivia", "last": "Johnson", "dob": "1994-07-21", "degree": "PhD in Linguistics"}
# aprendi_org_table<TEACHER#150, METADATA> {"first": "Eli", "last": "Turner", "dob": "2001-02-09", "degree": "PhD in Philosophy"}
# aprendi_org_table<TEACHER#100, METADATA> {"first": "Liam", "last": "Williams", "dob": "1985-09-15", "degree": "Masters of Science in Computer Science"}
# aprendi_org_table<STUDENT#109, METADATA> {"first": "Oliver", "last": "Martinez", "dob": "2000-04-02"}
# aprendi_org_table<STUDENT#141, METADATA> {"first": "Stella", "last": "Harris", "dob": "1998-11-08"}
# aprendi_org_table<TEACHER#123, METADATA> {"first": "Liam", "last": "Lee", "dob": "1999-07-03", "degree": "Masters of Science in Computer Science"}
# aprendi_org_table<COURSE#196, METADATA> {"course_name": "Visual Arts"}
# aprendi_org_table<STUDENT#115, METADATA> {"first": "Evelyn", "last": "Thomas", "dob": "1984-11-27"}
# aprendi_org_table<COURSE#198, METADATA> {"course_name": "Ceramics"}
# aprendi_org_table<STUDENT#113, METADATA> {"first": "Liam", "last": "Wilson", "dob": "1981-05-10"}
# aprendi_org_table<TEACHER#116, METADATA> {"first": "Elijah", "last": "Taylor", "dob": "1995-10-20", "degree": "PhD in Philosophy"}
# aprendi_org_table<COURSE#147, METADATA> {"course_name": "Culinary Arts"}
# aprendi_org_table<STUDENT#134, METADATA> {"first": "Naomi", "last": "Turner", "dob": "1984-03-23"}
# aprendi_org_table<TEACHER#151, METADATA> {"first": "Chloe", "last": "Scott", "dob": "1983-12-04", "degree": "Masters of Science in Computer Science"}
# aprendi_org_table<COURSE#116, METADATA> {"course_name": "Anatomy"}
# aprendi_org_table<STUDENT#128, METADATA> {"first": "Zoe", "last": "Hernandez", "dob": "1993-07-02"}
# aprendi_org_table<COURSE#148, METADATA> {"course_name": "Nutrition"}
# aprendi_org_table<STUDENT#167, METADATA> {"first": "Layla", "last": "Johnson", "dob": "1977-11-21"}
# aprendi_org_table<COURSE#143, METADATA> {"course_name": "Graphic Design"}
# aprendi_org_table<TEACHER#137, METADATA> {"first": "Aria", "last": "Smith", "dob": "2000-08-05", "degree": "Masters of Public Administration"}
# aprendi_org_table<STUDENT#142, METADATA> {"first": "Aiden", "last": "Martin", "dob": "1980-08-02"}
# aprendi_org_table<STUDENT#172, METADATA> {"first": "Sofia", "last": "Turner", "dob": "1997-12-18"}
# aprendi_org_table<COURSE#164, METADATA> {"course_name": "Oceanography"}
# aprendi_org_table<COURSE#165, METADATA> {"course_name": "Meteorology"}
# aprendi_org_table<STUDENT#121, METADATA> {"first": "Sofia", "last": "Rodriguez", "dob": "1973-11-16"}
# aprendi_org_table<COURSE#103, METADATA> {"course_name": "Physics"}
# aprendi_org_table<STUDENT#126, METADATA> {"first": "James", "last": "Allen", "dob": "1976-12-14"}
# aprendi_org_table<TEACHER#125, METADATA> {"first": "Grace", "last": "Hall", "dob": "1991-02-19", "degree": "Masters of Business Administration"}
# aprendi_org_table<COURSE#154, METADATA> {"course_name": "Theology"}
# aprendi_org_table<STUDENT#116, METADATA> {"first": "Elijah", "last": "Taylor", "dob": "1995-10-20"}
# aprendi_org_table<COURSE#136, METADATA> {"course_name": "Information Technology"}
# aprendi_org_table<COURSE#187, METADATA> {"course_name": "Real Estate"}
# aprendi_org_table<COURSE#145, METADATA> {"course_name": "Interior Design"}
# aprendi_org_table<COURSE#180, METADATA> {"course_name": "Adult Education"}
# aprendi_org_table<TEACHER#153, METADATA> {"first": "Owen", "last": "Clark", "dob": "1985-07-22", "degree": "Masters of Business Administration"}
# aprendi_org_table<COURSE#186, METADATA> {"course_name": "Urban Planning"}
# aprendi_org_table<TEACHER#109, METADATA> {"first": "Oliver", "last": "Martinez", "dob": "2000-04-02", "degree": "PhD in Chemistry"}
# aprendi_org_table<TEACHER#111, METADATA> {"first": "Aiden", "last": "Lopez", "dob": "1987-09-23", "degree": "PhD in Political Science"}
# aprendi_org_table<TEACHER#159, METADATA> {"first": "Sophia", "last": "Hall", "dob": "1982-05-13", "degree": "Masters of Political Science"}
# aprendi_org_table<STUDENT#130, METADATA> {"first": "Chloe", "last": "Wright", "dob": "1997-01-18"}
# aprendi_org_table<TEACHER#118, METADATA> {"first": "Michael", "last": "Harris", "dob": "1978-06-06", "degree": "PhD in History"}
# aprendi_org_table<COURSE#191, METADATA> {"course_name": "Tourism"}
# aprendi_org_table<TEACHER#166, METADATA> {"first": "James", "last": "Garcia", "dob": "1995-01-28", "degree": "PhD in Literature"}
# aprendi_org_table<STUDENT#153, METADATA> {"first": "Owen", "last": "Clark", "dob": "1985-07-22"}
# aprendi_org_table<STUDENT#159, METADATA> {"first": "Sophia", "last": "Hall", "dob": "1982-05-13"}
# aprendi_org_table<TEACHER#143, METADATA> {"first": "Ava", "last": "Thompson", "dob": "1994-05-26", "degree": "Masters of Education"}
# aprendi_org_table<COURSE#111, METADATA> {"course_name": "Sociology"}
# aprendi_org_table<TEACHER#127, METADATA> {"first": "Scarlett", "last": "Young", "dob": "1987-10-08", "degree": "Masters of Arts in Economics"}
# aprendi_org_table<STUDENT#163, METADATA> {"first": "Scarlett", "last": "Brown", "dob": "1986-08-17"}
# aprendi_org_table<COURSE#155, METADATA> {"course_name": "Medieval Studies"}
# aprendi_org_table<TEACHER#176, METADATA> {"first": "Nora", "last": "Walker", "dob": "1976-03-24", "degree": "PhD in Mathematics"}
# aprendi_org_table<STUDENT#120, METADATA> {"first": "Samuel", "last": "Clark", "dob": "1980-01-23"}
# aprendi_org_table<COURSE#161, METADATA> {"course_name": "European Studies"}
# aprendi_org_table<STUDENT#112, METADATA> {"first": "Amelia", "last": "Gonzalez", "dob": "1975-07-17"}
# aprendi_org_table<COURSE#151, METADATA> {"course_name": "Foreign Languages"}
# aprendi_org_table<TEACHER#144, METADATA> {"first": "Liam", "last": "Young", "dob": "1982-03-20", "degree": "PhD in Political Science"}
# aprendi_org_table<TEACHER#155, METADATA> {"first": "William", "last": "Williams", "dob": "1975-03-09", "degree": "Masters of Arts in Economics"}
# aprendi_org_table<TEACHER#172, METADATA> {"first": "Sofia", "last": "Turner", "dob": "1997-12-18", "degree": "PhD in Political Science"}
# aprendi_org_table<STUDENT#177, METADATA> {"first": "Zoe", "last": "White", "dob": "1988-01-17"}
# aprendi_org_table<TEACHER#108, METADATA> {"first": "Isabella", "last": "Rodriguez", "dob": "1977-08-14", "degree": "Masters of Fine Arts in Creative Writing"}
# aprendi_org_table<TEACHER#113, METADATA> {"first": "Liam", "last": "Wilson", "dob": "1981-05-10", "degree": "Masters of Social Work"}
# aprendi_org_table<COURSE#146, METADATA> {"course_name": "Fashion Design"}
# aprendi_org_table<COURSE#178, METADATA> {"course_name": "Early Childhood Education"}
# aprendi_org_table<TEACHER#148, METADATA> {"first": "Ethan", "last": "Thomas", "dob": "1971-06-23", "degree": "PhD in Mathematics"}
# aprendi_org_table<TEACHER#114, METADATA> {"first": "Harper", "last": "Anderson", "dob": "1997-02-03", "degree": "PhD in Astrophysics"}
# aprendi_org_table<COURSE#182, METADATA> {"course_name": "Animal Science"}
# aprendi_org_table<COURSE#140, METADATA> {"course_name": "Electrical Engineering"}
# aprendi_org_table<STUDENT#149, METADATA> {"first": "Ella", "last": "Wright", "dob": "1991-04-16"}
# aprendi_org_table<TEACHER#180, METADATA> {"first": "Samuel", "last": "King", "dob": "1978-06-27", "degree": "PhD in Environmental Science"}
# aprendi_org_table<TEACHER#102, METADATA> {"first": "Noah", "last": "Smith", "dob": "1988-03-10", "degree": "Masters of Business Administration"}
# aprendi_org_table<TEACHER#170, METADATA> {"first": "Emma", "last": "Thomas", "dob": "1991-05-02", "degree": "PhD in Computer Science"}
# aprendi_org_table<COURSE#190, METADATA> {"course_name": "Supply Chain Management"}
# aprendi_org_table<STUDENT#133, METADATA> {"first": "Leo", "last": "Adams", "dob": "1995-06-29"}
# aprendi_org_table<COURSE#162, METADATA> {"course_name": "Latin American Studies"}
# aprendi_org_table<COURSE#130, METADATA> {"course_name": "Communication Studies"}
# aprendi_org_table<TEACHER#145, METADATA> {"first": "Lily", "last": "Walker", "dob": "1996-01-13", "degree": "Masters of Architecture"}
# aprendi_org_table<COURSE#139, METADATA> {"course_name": "Mechanical Engineering"}
# aprendi_org_table<COURSE#171, METADATA> {"course_name": "Law"}
# aprendi_org_table<STUDENT#106, METADATA> {"first": "Mia", "last": "Miller", "dob": "1996-02-09"}
# aprendi_org_table<COURSE#163, METADATA> {"course_name": "Middle Eastern Studies"}
# aprendi_org_table<COURSE#105, METADATA> {"course_name": "Computer Science"}
# aprendi_org_table<STUDENT#135, METADATA> {"first": "Lucas", "last": "Perez", "dob": "1972-12-17"}
# aprendi_org_table<STUDENT#173, METADATA> {"first": "Liam", "last": "Jackson", "dob": "1985-10-12"}
# aprendi_org_table<STUDENT#158, METADATA> {"first": "Nathan", "last": "Adams", "dob": "1996-07-20"}
# aprendi_org_table<COURSE#106, METADATA> {"course_name": "History"}
# aprendi_org_table<COURSE#124, METADATA> {"course_name": "Anthropology"}
# aprendi_org_table<COURSE#134, METADATA> {"course_name": "Marketing"}
# aprendi_org_table<TEACHER#138, METADATA> {"first": "Julian", "last": "Gonzalez", "dob": "1992-05-28", "degree": "PhD in Literature"}
# aprendi_org_table<COURSE#122, METADATA> {"course_name": "Zoology"}
# aprendi_org_table<STUDENT#118, METADATA> {"first": "Michael", "last": "Harris", "dob": "1978-06-06"}
# aprendi_org_table<COURSE#157, METADATA> {"course_name": "Modern History"}
# aprendi_org_table<COURSE#137, METADATA> {"course_name": "Software Engineering"}
# aprendi_org_table<STUDENT#151, METADATA> {"first": "Chloe", "last": "Scott", "dob": "1983-12-04"}
# aprendi_org_table<TEACHER#120, METADATA> {"first": "Samuel", "last": "Clark", "dob": "1980-01-23", "degree": "PhD in Mathematics"}
# aprendi_org_table<COURSE#104, METADATA> {"course_name": "Mathematics"}
# aprendi_org_table<TEACHER#149, METADATA> {"first": "Ella", "last": "Wright", "dob": "1991-04-16", "degree": "Masters of Science in Nursing"}
# aprendi_org_table<TEACHER#126, METADATA> {"first": "James", "last": "Allen", "dob": "1976-12-14", "degree": "PhD in Psychology"}
# aprendi_org_table<STUDENT#156, METADATA> {"first": "Victoria", "last": "Garcia", "dob": "1988-12-02"}
# aprendi_org_table<TEACHER#136, METADATA> {"first": "Grace", "last": "Martinez", "dob": "1988-10-11", "degree": "PhD in Anthropology"}
# aprendi_org_table<STUDENT#171, METADATA> {"first": "Max", "last": "Martin", "dob": "1983-02-24"}
# aprendi_org_table<COURSE#152, METADATA> {"course_name": "Linguistics"}
# aprendi_org_table<COURSE#131, METADATA> {"course_name": "Business Administration"}
# aprendi_org_table<COURSE#192, METADATA> {"course_name": "Hotel Management"}
# aprendi_org_table<TEACHER#179, METADATA> {"first": "Eli", "last": "Clark", "dob": "1992-09-03", "degree": "Masters of Science in Computer Science"}
# aprendi_org_table<TEACHER#147, METADATA> {"first": "Aria", "last": "Moore", "dob": "1989-08-30", "degree": "Masters of Social Work"}
# aprendi_org_table<STUDENT#111, METADATA> {"first": "Aiden", "last": "Lopez", "dob": "1987-09-23"}
# aprendi_org_table<TEACHER#169, METADATA> {"first": "Ava", "last": "Wilson", "dob": "1973-07-08", "degree": "Masters of Science in Environmental Science"}
# aprendi_org_table<STUDENT#125, METADATA> {"first": "Grace", "last": "Hall", "dob": "1991-02-19"}
# aprendi_org_table<COURSE#128, METADATA> {"course_name": "Film Studies"}
# aprendi_org_table<COURSE#138, METADATA> {"course_name": "Civil Engineering"}
# aprendi_org_table<STUDENT#164, METADATA> {"first": "Lincoln", "last": "Miller", "dob": "1998-06-10"}
# aprendi_org_table<TEACHER#154, METADATA> {"first": "Ellie", "last": "King", "dob": "1993-05-15", "degree": "PhD in Psychology"}
# aprendi_org_table<STUDENT#169, METADATA> {"first": "Ava", "last": "Wilson", "dob": "1973-07-08"}
# aprendi_org_table<STUDENT#150, METADATA> {"first": "Eli", "last": "Turner", "dob": "2001-02-09"}
# aprendi_org_table<COURSE#173, METADATA> {"course_name": "Social Work"}
# aprendi_org_table<COURSE#197, METADATA> {"course_name": "Photography"}
# aprendi_org_table<STUDENT#152, METADATA> {"first": "Evelyn", "last": "Harris", "dob": "1999-09-28"}
# aprendi_org_table<STUDENT#100, METADATA> {"first": "Liam", "last": "Williams", "dob": "1985-09-15"}
# aprendi_org_table<COURSE#183, METADATA> {"course_name": "Forestry"}
# aprendi_org_table<COURSE#101, METADATA> {"course_name": "Biology"}
# aprendi_org_table<TEACHER#119, METADATA> {"first": "Abigail", "last": "Martin", "dob": "1992-03-30", "degree": "Masters of Science in Nursing"}
# aprendi_org_table<STUDENT#101, METADATA> {"first": "Olivia", "last": "Johnson", "dob": "1994-07-21"}
# aprendi_org_table<TEACHER#171, METADATA> {"first": "Max", "last": "Martin", "dob": "1983-02-24", "degree": "Masters of Education"}
# aprendi_org_table<COURSE#175, METADATA> {"course_name": "Public Health"}
# aprendi_org_table<COURSE#125, METADATA> {"course_name": "Archaeology"}
# aprendi_org_table<STUDENT#131, METADATA> {"first": "Jackson", "last": "Ward", "dob": "1981-11-11"}
# aprendi_org_table<STUDENT#166, METADATA> {"first": "James", "last": "Garcia", "dob": "1995-01-28"}
# aprendi_org_table<COURSE#114, METADATA> {"course_name": "Art History"}
# aprendi_org_table<COURSE#115, METADATA> {"course_name": "Music Theory"}
# aprendi_org_table<TEACHER#128, METADATA> {"first": "Zoe", "last": "Hernandez", "dob": "1993-07-02", "degree": "PhD in Creative Writing"}
# aprendi_org_table<COURSE#110, METADATA> {"course_name": "Psychology"}
# aprendi_org_table<TEACHER#156, METADATA> {"first": "Victoria", "last": "Garcia", "dob": "1988-12-02", "degree": "PhD in Creative Writing"}
# aprendi_org_table<COURSE#109, METADATA> {"course_name": "Philosophy"}
# aprendi_org_table<COURSE#118, METADATA> {"course_name": "Geology"}
# aprendi_org_table<COURSE#195, METADATA> {"course_name": "Dance"}
# aprendi_org_table<STUDENT#124, METADATA> {"first": "Avery", "last": "Walker", "dob": "1982-04-27"}
# aprendi_org_table<COURSE#159, METADATA> {"course_name": "African Studies"}
# aprendi_org_table<TEACHER#160, METADATA> {"first": "Lucas", "last": "Perez", "dob": "1970-03-06", "degree": "PhD in Biology"}
# aprendi_org_table<TEACHER#140, METADATA> {"first": "Adam", "last": "Miller", "dob": "1974-01-15", "degree": "PhD in Economics"}
# aprendi_org_table<COURSE#129, METADATA> {"course_name": "Journalism"}
# aprendi_org_table<STUDENT#144, METADATA> {"first": "Liam", "last": "Young", "dob": "1982-03-20"}
# aprendi_org_table<COURSE#126, METADATA> {"course_name": "Classical Studies"}
# aprendi_org_table<TEACHER#157, METADATA> {"first": "Ella", "last": "Lopez", "dob": "1980-09-26", "degree": "Masters of Science in Chemistry"}
# aprendi_org_table<TEACHER#178, METADATA> {"first": "Emma", "last": "Thompson", "dob": "2000-11-10", "degree": "PhD in Philosophy"}
# aprendi_org_table<TEACHER#158, METADATA> {"first": "Nathan", "last": "Adams", "dob": "1996-07-20", "degree": "PhD in Education"}
# aprendi_org_table<TEACHER#132, METADATA> {"first": "Victoria", "last": "Mitchell", "dob": "1979-09-05", "degree": "PhD in Biology"}
# aprendi_org_table<TEACHER#103, METADATA> {"first": "Emma", "last": "Brown", "dob": "1979-12-05", "degree": "Masters of Science in Electrical Engineering"}
# aprendi_org_table<TEACHER#124, METADATA> {"first": "Avery", "last": "Walker", "dob": "1982-04-27", "degree": "PhD in Environmental Science"}
# aprendi_org_table<TEACHER#110, METADATA> {"first": "Sophia", "last": "Hernandez", "dob": "1993-01-28", "degree": "Masters of Education"}
# aprendi_org_table<TEACHER#139, METADATA> {"first": "Layla", "last": "Campbell", "dob": "1986-03-22", "degree": "Masters of Music"}
# aprendi_org_table<COURSE#149, METADATA> {"course_name": "Physical Education"}
# aprendi_org_table<STUDENT#155, METADATA> {"first": "William", "last": "Williams", "dob": "1975-03-09"}
# aprendi_org_table<TEACHER#173, METADATA> {"first": "Liam", "last": "Jackson", "dob": "1985-10-12", "degree": "Masters of Architecture"}
# aprendi_org_table<COURSE#144, METADATA> {"course_name": "Industrial Design"}
# aprendi_org_table<STUDENT#136, METADATA> {"first": "Grace", "last": "Martinez", "dob": "1988-10-11"}
# aprendi_org_table<STUDENT#140, METADATA> {"first": "Adam", "last": "Miller", "dob": "1974-01-15"}
# aprendi_org_table<TEACHER#106, METADATA> {"first": "Mia", "last": "Miller", "dob": "1996-02-09", "degree": "Masters of Science in Biology"}
# aprendi_org_table<COURSE#170, METADATA> {"course_name": "Veterinary Science"}
# aprendi_org_table<STUDENT#108, METADATA> {"first": "Isabella", "last": "Rodriguez", "dob": "1977-08-14"}
# aprendi_org_table<TEACHER#163, METADATA> {"first": "Scarlett", "last": "Brown", "dob": "1986-08-17", "degree": "Masters of Science in Physics"}
# aprendi_org_table<STUDENT#170, METADATA> {"first": "Emma", "last": "Thomas", "dob": "1991-05-02"}
# aprendi_org_table<COURSE#121, METADATA> {"course_name": "Marine Biology"}
# aprendi_org_table<COURSE#117, METADATA> {"course_name": "Physiology"}
# aprendi_org_table<STUDENT#178, METADATA> {"first": "Emma", "last": "Thompson", "dob": "2000-11-10"}
# aprendi_org_table<STUDENT#127, METADATA> {"first": "Scarlett", "last": "Young", "dob": "1987-10-08"}
# aprendi_org_table<TEACHER#104, METADATA> {"first": "Lucas", "last": "Jones", "dob": "1998-11-18", "degree": "PhD in Psychology"}
# aprendi_org_table<COURSE#184, METADATA> {"course_name": "Environmental Studies"}
# aprendi_org_table<STUDENT#117, METADATA> {"first": "Charlotte", "last": "Lee", "dob": "1986-08-13"}
# aprendi_org_table<STUDENT#122, METADATA> {"first": "Evelyn", "last": "Lewis", "dob": "1989-09-09"}
# aprendi_org_table<STUDENT#139, METADATA> {"first": "Layla", "last": "Campbell", "dob": "1986-03-22"}
# aprendi_org_table<TEACHER#117, METADATA> {"first": "Charlotte", "last": "Lee", "dob": "1986-08-13", "degree": "Masters of Architecture"}
# aprendi_org_table<TEACHER#162, METADATA> {"first": "Avery", "last": "Ward", "dob": "1992-10-23", "degree": "PhD in Sociology"}
# aprendi_org_table<COURSE#135, METADATA> {"course_name": "Human Resources"}
# aprendi_org_table<COURSE#174, METADATA> {"course_name": "Public Administration"}
# aprendi_org_table<COURSE#132, METADATA> {"course_name": "Accounting"}
# aprendi_org_table<STUDENT#157, METADATA> {"first": "Ella", "last": "Lopez", "dob": "1980-09-26"}
# aprendi_org_table<STUDENT#107, METADATA> {"first": "Ethan", "last": "Davis", "dob": "1989-10-31"}
# aprendi_org_table<TEACHER#165, METADATA> {"first": "Eva", "last": "Moore", "dob": "1981-04-03", "degree": "Masters of Public Administration"}
# aprendi_org_table<STUDENT#146, METADATA> {"first": "Lincoln", "last": "White", "dob": "1977-11-06"}
# aprendi_org_table<COURSE#100, METADATA> {"course_name": "Creative Writing"}
# aprendi_org_table<STUDENT#138, METADATA> {"first": "Julian", "last": "Gonzalez", "dob": "1992-05-28"}
# aprendi_org_table<STUDENT#176, METADATA> {"first": "Nora", "last": "Walker", "dob": "1976-03-24"}
# aprendi_org_table<COURSE#102, METADATA> {"course_name": "Chemistry"}
# aprendi_org_table<STUDENT#154, METADATA> {"first": "Ellie", "last": "King", "dob": "1993-05-15"}
# aprendi_org_table<STUDENT#104, METADATA> {"first": "Lucas", "last": "Jones", "dob": "1998-11-18"}
# aprendi_org_table<COURSE#150, METADATA> {"course_name": "Sports Management"}
